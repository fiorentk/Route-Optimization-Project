# %%
import pandas as pd

df = pd.read_csv('sampel2.csv', dtype=str)

# %%
data = {
    "nama_kantor": [],
    "latitude": [],
    "longitude": []
}
df_kantor = pd.DataFrame(data)

new_data = {
    "nama_kantor": "DC CIPEDES",
    "latitude": -6.894104,
    "longitude": 107.590074
}
df_kantor = pd.concat([df_kantor, pd.DataFrame([new_data])], ignore_index=True)

# %%
df['id_kurir'] = df['pod__photo'].str.extract(r'camera\.photoDeliveryProcessImage\.(\d+)')
df['pod__timereceive'] = pd.to_datetime(df['pod__timereceive'])
df['date'] = df['pod__timereceive'].dt.date
df['date'] = df['date'].astype(str)

# %%
df_cipedes = df[df["connote__connote_receiver_address_detail"].str.contains("cipedes", case=False, na=False)]

# %%
df_cipedes.head()
# Out:
#     connote__connote_code connote__connote_receiver_name  \
# 51         P2410100214334                   Fina nursyam
# 116        P2410100126053          hendra jatnika aripin
# 123        P2410100170522       PIMP KIRANA WIJAYA ABADI
# 131        P2410100208955   PT BIRO ARSITEK DAN INSINJUR
# 414        P2410100079765              NITA PUSPITA SARI
#
#                      connote__connote_receiver_address  \
# 51   Kost Pak Asep  Jalan Haji Yasin No  37  RT 2 R...
# 116  jalan sukamukti no 10 kota bandung toko kue sa...
# 123                        JL KARANGTINEUNG NO 106/181
# 131                            JL KARANG TINGGAL NO 23
# 414  JL  SUKAGALIH GG H GOJALI NO 318  DEKAT    MAS...
#
#     connote__connote_receiver_address_detail connote__connote_state  \
# 51           KOTA BANDUNG, SUKAJADI, CIPEDES              DELIVERED
# 116          KOTA BANDUNG, SUKAJADI, CIPEDES              DELIVERED
# 123          KOTA BANDUNG, SUKAJADI, CIPEDES              DELIVERED
# 131          KOTA BANDUNG, SUKAJADI, CIPEDES              DELIVERED
# 414          KOTA BANDUNG, SUKAJADI, CIPEDES              DELIVERED
#
#     connote__connote_service custom_field__destination_nopen  \
# 51                       EC3                           40000
# 116                       PE                           40000
# 123                      PKH                           40000
# 131                       PE                           40000
# 414                      PKH                           40000
#
#        pod__timereceive         pod__coordinate  \
# 51  2024-10-11 10:50:48  -6.8946996,107.5928567
# 116 2024-10-11 11:09:02  -6.8994175,107.5966994
# 123 2024-10-11 11:55:11   -6.8848883,107.594156
# 131 2024-10-11 11:43:54  -6.8859139,107.5951169
# 414 2024-10-11 13:47:49  -6.8897819,107.5929289
#
#                                             pod__photo   id_kurir        date
# 51   https://apistorage.mile.app/v2-public/prod/pos...  560001282  2024-10-11
# 116  https://apistorage.mile.app/v2-public/prod/pos...  560001282  2024-10-11
# 123  https://apistorage.mile.app/v2-public/prod/pos...  560001282  2024-10-11
# 131  https://apistorage.mile.app/v2-public/prod/pos...  560001282  2024-10-11
# 414  https://apistorage.mile.app/v2-public/prod/pos...  560001282  2024-10-11

# %%
# Hitung jumlah total per 'id_kurir' dan 'date'
grouped_df_cipedes = (
    df_cipedes.groupby(['id_kurir', 'date'], as_index=False)
    .agg(count=('date', 'size'))
)
grouped_df_cipedes
# Out:
#      id_kurir        date  count
# 0   560001282  2024-10-11     17
# 1   560001282  2024-10-12     24
# 2   560001282  2024-10-13     14
# 3   560001282  2024-10-14      8
# 4   560001282  2024-10-15     13
# 5   560001282  2024-10-16     18
# 6   560001282  2024-10-17     15
# 7   560001282  2024-10-18     20
# 8   560001282  2024-10-19     17
# 9   560001387  2024-10-11      6
# 10  560001387  2024-10-12      5
# 11  560001387  2024-10-14      2
# 12  560001387  2024-10-15      3
# 13  560001387  2024-10-16      2
# 14  560001387  2024-10-17      2
# 15  560001534  2024-10-12     25
# 16  560005605  2024-10-12      3
# 17  560005605  2024-10-15      1
# 18  560007025  2024-10-11      1
# 19  560007025  2024-10-12      1
# 20  560007101  2024-10-11      3
# 21  560007101  2024-10-12      5
# 22  560007101  2024-10-14      1
# 23  560007101  2024-10-15      2
# 24  560007101  2024-10-16      2
# 25  560007101  2024-10-17      7
# 26  560007660  2024-10-12      2
# 27  560007660  2024-10-17      1
# 28  560007668  2024-10-12      1
# 29  560007950  2024-10-12      4
# 30  560007950  2024-10-15      1
# 31  560007950  2024-10-16      1
# 32  560008250  2024-10-12      2
# 33  560008843  2024-10-11      1
# 34  560018057  2024-10-12      4
# 35  560022106  2024-10-12      1
# 36  560022592  2024-10-19      1
# 37  560030229  2024-10-12      1

# %%
kurir = ['560001282']
df_coba_cipedes = df_cipedes[df_cipedes['id_kurir'].isin(kurir)]
df_coba_cipedess = df_coba_cipedes.drop(columns=['id_kurir','date'])
df_coba_cipedess.shape
# Out:
# (146, 10)

# %%
df_coba_cipedes1 = df_coba_cipedes[(df_coba_cipedes['id_kurir']=='560001282') & (df_coba_cipedes['date']=='2024-10-11')]
df_coba_cipedes1 = df_coba_cipedes1.drop(columns=['id_kurir','date'])
df_coba_cipedes1.shape
# Out:
# (17, 10)

# %%
from modul_tsp_kantor import predict_optimal_route

result_geopy = predict_optimal_route(df_coba_cipedes1, df_kantor)

# %%
from modul_tsp_OSRM import predict_optimal_route

result_OSRM = predict_optimal_route(df_coba_cipedes1, df_kantor)

# %%
result_OSRM
# Out:
#   courier_id        date                                     route_original  \
# 0  560001282  2024-10-11  [DC CIPEDES, P2410100214334, P2410100126053, P...
#
#    total_distance_original (meters)  \
# 0                             39948
#
#                                        route_optimal  \
# 0  [DC CIPEDES, P2410100169635, P2410100126053, P...
#
#    total_distance_optimal (meters)  distance_difference (meters)  \
# 0                            13322                         26626
#
#   route_efficiency  fuel_savings (liter)  cost_savings (rupiah)
# 0           66.65%                  0.67                   8710

# %%
result_geopy
# Out:
#   courier_id        date                                     route_original  \
# 0  560001282  2024-10-11  [DC CIPEDES, P2410100214334, P2410100126053, P...
#
#    total_distance_original (meters)  \
# 0                             14238
#
#                                        route_optimal  \
# 0  [DC CIPEDES, P2410100169635, P2410100214334, P...
#
#    total_distance_optimal (meters)  distance_difference (meters)  \
# 0                             4923                          9315
#
#   route_efficiency  fuel_savings (liter)  cost_savings (rupiah)
# 0           65.42%                  0.23                   2990
